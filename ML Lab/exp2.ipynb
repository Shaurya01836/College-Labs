# %%
import pandas as pd 

data = pd.read_csv('data.csv')

data
# Out:
#      SKY AIR_TEMP HUMIDITY    WIND WATER FORECAST TARGET_VALUE
# 0  Sunny     Warm   Normal  Strong  Warm     Same          Yes
# 1  Sunny     Warm     High  Strong  Warm     Same          Yes
# 2  Rainy     Cold     High  Strong  Warm     Same           No
# 3  Sunny     Warm     High  Strong  Cold   Change          Yes

# %%
import numpy as np 

array = np.array(data)[: , :-1]
array
# Out:
# array([['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same'],
#        ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same'],
#        ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Same'],
#        ['Sunny', 'Warm', 'High', 'Strong', 'Cold', 'Change']],
#       dtype=object)

# %%
target = np.array(data)[: , -1]
target
# Out:
# array(['Yes', 'Yes', 'No', 'Yes'], dtype=object)

# %%
print("The attributes are : " , array)
num_attribute = len(array[0])
print("Number of attributes" , num_attribute)
# Out:
# The attributes are :  [['Sunny' 'Warm' 'Normal' 'Strong' 'Warm' 'Same']
#  ['Sunny' 'Warm' 'High' 'Strong' 'Warm' 'Same']
#  ['Rainy' 'Cold' 'High' 'Strong' 'Warm' 'Same']
#  ['Sunny' 'Warm' 'High' 'Strong' 'Cold' 'Change']]
# Number of attributes 6

# %%
print("The initial hypothesis is :")
hypothesis = ['0']*num_attribute 
print(hypothesis)
# Out:
# The initial hypothesis is :
# ['0', '0', '0', '0', '0', '0']

# %%
target = np.array(data)[: , -1]
target
# Out:
# array(['Yes', 'Yes', 'No', 'Yes'], dtype=object)

# %%
def learn(array, target):
    specific_h = array[0].copy()
    general_h = [["?" for i in range(len(specific_h))]
                 for i in range(len(specific_h))]
    print("initialization of specific_h and general_h")
    print(specific_h)
    print(general_h)

    for i, h in enumerate(array):
        if target[i] == "Yes":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    specific_h[x] = '?'
                    general_h[x][x] = '?'
                    print(specific_h)
                    print(general_h)

        if target[i] == "No":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'
                    print("step of Candidate Elimination Algorithm", i+1)
                    print(specific_h)
                    print(general_h)

    indices = [i for i, val in enumerate(general_h)
        if val == ['?', '?', '?', '?', '?', '?']]
    for i in indices:
        general_h.remove(['?', '?', '?', '?', '?', '?'])
    return specific_h, general_h

s_final, g_final = learn(array, target)
print("Final specific_h:", s_final, sep="\n")
print("Final general_h:", g_final, sep="\n")
# Out:
# initialization of specific_h and general_h
# ['Sunny' 'Warm' 'Normal' 'Strong' 'Warm' 'Same']
# [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
# ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
# [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
# step of Candidate Elimination Algorithm 3
# ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
# [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
# step of Candidate Elimination Algorithm 3
# ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
# ...
